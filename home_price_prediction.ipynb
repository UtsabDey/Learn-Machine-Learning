# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("data_set/homeprices.csv")

reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)

plt.xlabel('area(sqft)')
plt.ylabel('price(USD)')
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area, reg.predict(df[['area']]), color='blue')
plt.show()

# %%
area_df = pd.DataFrame([[3500]], columns=['area'])
price = reg.predict(area_df)

plt.xlabel('area(sqft)')
plt.ylabel('price(USD)')

# original data
plt.scatter(df.area, df.price, color='red', marker='+')

# regression line
plt.plot(df.area, reg.predict(df[['area']]), color='blue')

# your predicted point
plt.scatter(area, price, color='green', s=100)

plt.show()

# %%
reg. coef_ # slope (m)
reg. intercept_ # intercept (b)

# price = m * area + b
135.78767123*3500+180616.43835616432
# Out:
# 655873.2876611643

# %%
d = pd.read_csv("content/areas.csv")
p = reg.predict(d)
d['prices'] = p
for i in range(len(d)):
    print(f"Area: {d.area[i]} sqft → Predicted Price: {d.prices[i]:,.2f} USD")
# Out:
# Area: 1000 sqft → Predicted Price: 316,404.11 USD
# Area: 1500 sqft → Predicted Price: 384,297.95 USD
# Area: 2300 sqft → Predicted Price: 492,928.08 USD
# Area: 3540 sqft → Predicted Price: 661,304.79 USD
# Area: 4120 sqft → Predicted Price: 740,061.64 USD
# Area: 4560 sqft → Predicted Price: 799,808.22 USD
# Area: 5490 sqft → Predicted Price: 926,090.75 USD
# Area: 3460 sqft → Predicted Price: 650,441.78 USD
# Area: 4750 sqft → Predicted Price: 825,607.88 USD
# Area: 2300 sqft → Predicted Price: 492,928.08 USD
# Area: 9000 sqft → Predicted Price: 1,402,705.48 USD
# Area: 8600 sqft → Predicted Price: 1,348,390.41 USD
# Area: 7100 sqft → Predicted Price: 1,144,708.90 USD

# %%
d.to_csv("data_set/prediction.csv", index=False)
