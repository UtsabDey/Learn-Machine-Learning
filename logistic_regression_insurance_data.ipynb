# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data_set/insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'], df['bought_insurance'], marker='+', color='red')
plt.xlabel('age')
plt.ylabel('bought_insurance')
plt.title('Age vs Bought Insurance')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=0.2)

# %%
X_test
# Out:
#     age
# 4    46
# 22   40
# 17   58
# 13   29
# 10   18
# 21   26

# %%
X_train.head()
# Out:
#     age
# 16   25
# 25   54
# 9    61
# 3    52
# 12   27

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1, 0, 0, 0])

# %%
print('Train score: ', model.score(X_train, y_train))
print('Test score: ', model.score(X_test, y_test))
# Out:
# Train score:  0.8571428571428571
# Test score:  1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.32678835, 0.67321165],
#        [0.49711158, 0.50288842],
#        [0.10478685, 0.89521315],
#        [0.78453631, 0.21546369],
#        [0.93061369, 0.06938631],
#        [0.83860663, 0.16139337]])

# %%
model.predict([[30]])
# Out:
# d:\Web-Dev\Learn Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# Lets defined sigmoid function now and do the math with hand

# %%
coefficient = model.coef_
intercept = model.intercept_
print('Coefficient: ', coefficient)
print('Intercept: ', intercept)
# Out:
# Coefficient:  [[0.11853221]]
# Intercept:  [-4.72973443]

# %%
import numpy as np
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def prediction_function(age):
    z = coefficient * age + intercept
    predicted = sigmoid(z)
    return predicted

# %%
age = 48
prediction_function(age)
# Out:
# array([[0.72308406]])
